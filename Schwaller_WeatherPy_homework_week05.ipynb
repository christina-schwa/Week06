# %% [markdown]
# # Assignment - What's the Weather Like?
#
# ## Background
#
# Whether financial, political, or social -- data's true power lies in its ability to answer questions definitively. So let's take what you've learned about Python requests, APIs, and JSON traversals to answer a fundamental question: "What's the weather like as we approach the equator?"
#
# Now, we know what you may be thinking: _"Duh. It gets hotter..."_
#
# But, if pressed, how would you **provide evidence**?
#
# ## WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * OPTIONAL: Include a print log of each city as it's being processed with the city number and city name.
# * OPTIONAL: Save both a CSV of all data retrieved and png images for each scatter plot.
#
# As final considerations:
#
# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib ,Seaborn or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
#
# ## Hints and Considerations
#
# * The city data is generated based on random coordinates; as such, your outputs will not be an exact match to the provided starter notebook.
#
# * You may want to start this assignment by refreshing yourself on the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).
#
# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.
#
# * A starter code for Citipy has been provided. However, if you're craving an extra challenge, push yourself to learn how it works: [citipy Python library](https://pypi.python.org/pypi/citipy).
#
# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Don't modify this cell.
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Don't modify this cell
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# A lot of starter code has been generated for you. Use the cell below to play with the data to ensure you know what's happening.

# %%
print(cities)
# Out:
# ['jamestown', 'ushuaia', 'vila do maio', 'ngaoundere', 'kapaa', 'beyneu', 'dubbo', 'devarkonda', 'san quintin', 'barrow', 'albany', 'bubaque', 'rikitea', 'bluff', 'east london', 'honningsvag', 'necochea', 'starobaltachevo', 'catamarca', 'nikolskoye', 'ribeira grande', 'port alfred', 'wajima', 'balkanabat', 'port elizabeth', 'new norfolk', 'tuktoyaktuk', 'beringovskiy', 'saleaula', 'hasaki', 'amapa', 'jalu', 'matamoros', 'hermanus', 'kisangani', 'cabo san lucas', 'punta arenas', 'tasiilaq', 'lompoc', 'kodiak', 'castro', 'charters towers', 'umzimvubu', 'ulladulla', 'plettenberg bay', 'ostrovnoy', 'songea', 'raudeberg', 'saint-pierre', 'waingapu', 'lolua', 'temaraia', 'raduzhnyy', 'avarua', 'hilo', 'dakar', 'upernavik', 'klaksvik', 'altay', 'avera', 'bambous virieux', 'alta floresta', 'belushya guba', 'guerrero negro', 'saint george', 'butaritari', 'asau', 'bontang', 'airai', 'saint-philippe', 'samarai', 'devonport', 'karaul', 'scottsburgh', 'carnarvon', 'cape town', 'jiuquan', 'namibe', 'taolanaro', 'muzquiz', 'barentsburg', 'ilulissat', 'qaanaaq', 'chapais', 'mitchell', 'carutapera', 'vaini', 'hobart', 'amderma', 'mar del plata', 'saskylakh', 'yinchuan', 'yerbogachen', 'pangai', 'balikpapan', 'ghanaur', 'tonj', 'ancona', 'saldanha', 'grand centre', 'natal', 'yarumal', 'esperance', 'tura', 'codrington', 'ballina', 'illoqqortoormiut', 'comodoro rivadavia', 'constitucion', 'areka', 'mataura', 'obo', 'yaan', 'hillsborough', 'chokurdakh', 'christchurch', 'kavieng', 'la ronge', 'tsihombe', 'vanimo', 'muisne', 'kieta', 'vientiane', 'nanortalik', 'omsukchan', 'boa vista', 'brae', 'cidreira', 'bairiki', 'busselton', 'mahebourg', 'hazorasp', 'cape canaveral', 'kjollefjord', 'nouakchott', 'dingle', 'pisco', 'nome', 'tubruq', 'aklavik', 'yellowknife', 'araguari', 'meulaboh', 'dikson', 'killybegs', 'milove', 'spokane', 'kathu', 'dunedin', 'georgetown', 'boca do acre', 'paradwip', 'qaqortoq', 'kawakawa', 'dannenberg', 'borazjan', 'sisimiut', 'bani walid', 'kirakira', 'bredasdorp', 'pereslavl-zalesskiy', 'lincoln', 'pozo colorado', 'norman wells', 'luderitz', 'geraldton', 'ust-kamchatsk', 'dhenkanal', 'atuona', 'hailar', 'katsuura', 'nola', 'baykit', 'great yarmouth', 'wilmington', 'havre-saint-pierre', 'cuamba', 'trairi', 'sechura', 'namatanai', 'hofn', 'najran', 'ceuasul-de campie', 'tilichiki', 'ancud', 'port blair', 'provideniya', 'todos santos', 'gumusyaka', 'sulangan', 'campo maior', 'cockburn town', 'severo-yeniseyskiy', 'biak', 'puerto ayora', 'nizhneangarsk', 'araouane', 'bengkulu', 'marcona', 'sentyabrskiy', 'yirol', 'quatre cocos', 'peace river', 'hobyo', 'lebu', 'kununurra', 'kanbe', 'bud', 'taoudenni', 'san carlos del zulia', 'kiunga', 'alice springs', 'ixtapa', 'coihaique', 'praya', 'thompson', 'grand river south east', 'marsh harbour', 'kokkinon', 'ukiah', 'lakatoro', 'mwene-ditu', 'tuatapere', 'port lincoln', 'monchegorsk', 'nishihara', 'krasnoselkup', 'nabire', 'totness', 'te anau', 'berdychiv', 'hithadhoo', 'angoche', 'santa maria la alta', 'sitka', 'kloulklubed', 'elmadag', 'shache', 'qandala', 'azimur', 'luanda', 'nelson bay', 'chicama', 'aksarka', 'tutoia', 'svetlogorsk', 'jacareacanga', 'muros', 'fujin', 'hearst', 'gushikawa', 'puerto madero', 'bandarbeyla', 'byron bay', 'boende', 'teya', 'tingi', 'portland', 'lata', 'olafsvik', 'fortuna', 'fernandez', 'vicksburg', 'maniitsoq', 'yulara', 'murindo', 'labis', 'nurota', 'tarudant', 'tazovskiy', 'tiksi', 'roma', 'sterling', 'bethel', 'cherskiy', 'dubno', 'hami', 'anaconda', 'vaitupu', 'severo-kurilsk', 'bathsheba', 'dhidhdhoo', 'erenhot', 'kuche', 'sur', 'shenzhen', 'palmer', 'udomlya', 'ponta do sol', 'ossora', 'ygatimi', 'takoradi', 'pevek', 'gisborne', 'pampas', 'velikiy novgorod', 'chuy', 'lorengau', 'lakes entrance', 'clyde river', 'turtkul', 'garwa', 'aguie', 'abu dhabi', 'alyangula', 'puerto escondido', 'nikolayevsk-na-amure', 'terrace bay', 'farsund', 'griffith', 'cervo', 'weligama', 'basqal', 'sao jose da coroa grande', 'harper', 'imbituba', 'kazalinsk', 'paamiut',  ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city in `cities` using a series of successive API calls.
# * OPTIONAL: Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import time
# OpenWeatherMap API Key
api_key = api_keys.api_key

# base url for getting api data
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# example request
req = requests.get(base_url + f'&q={cities[0]}').json()

#Create empty list
city_data = []

# Your code here. A loop maybe? 
#NOTE: API calls can be slow. They can also be limited. Once you have a list try not to rerun all API calls very often. 

#Note from class: if/else would work, but try/except is better.
for i, city in enumerate(cities):
    
    try:
        city_url = base_url + f"&q={cities[i]}"
        print(city_url)
        request = requests.get(city_url).json()
              

        latitude = request["coord"]["lat"]
        longitude = request["coord"]["lon"]
        temperature = request["main"]["temp"]
        humidity = request["main"]["humidity"]
        cloudiness = request["clouds"]["all"]
        windspeed = request["wind"]["speed"]

       #city_data DOT append
        city_data.append({"City":city,
                        "latitude":latitude,
                        "longitude":longitude,
                        "temperature":temperature,
                        "humidity":humidity,
                        "cloudiness":cloudiness,
                        "wind speed":windspeed})
            
        print("working on city " + city)

    except Exception as e:
        print("city not found: " + city)
        print(e)
        
        pass
    
    time.sleep(1)

    
#locked out again!
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=jamestown
# working on city jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ushuaia
# working on city ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=vila do maio
# working on city vila do maio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ngaoundere
# working on city ngaoundere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kapaa
# working on city kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=beyneu
# working on city beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dubbo
# working on city dubbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=devarkonda
# working on city devarkonda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=san quintin
# working on city san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=barrow
# working on city barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=albany
# working on city albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bubaque
# working on city bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=rikitea
# working on city rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bluff
# working on city bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=east london
# working on city east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=honningsvag
# working on city honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=necochea
# working on city necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=starobaltachevo
# working on city starobaltachevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=catamarca
# working on city catamarca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nikolskoye
# working on city nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ribeira grande
# working on city ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=port alfred
# working on city port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=wajima
# working on city wajima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=balkanabat
# working on city balkanabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=port elizabeth
# working on city port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=new norfolk
# working on city new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tuktoyaktuk
# working on city tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=beringovskiy
# working on city beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=saleaula
# city not found: saleaula
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hasaki
# working on city hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=amapa
# working on city amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=jalu
# working on city jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=matamoros
# working on city matamoros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hermanus
# working on city hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kisangani
# working on city kisangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=cabo san lucas
# working on city cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=punta arenas
# working on city punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tasiilaq
# working on city tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=lompoc
# working on city lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kodiak
# working on city kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=castro
# working on city castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=charters towers
# working on city charters towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=umzimvubu
# city not found: umzimvubu
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ulladulla
# working on city ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=plettenberg bay
# working on city plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ostrovnoy
# working on city ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=songea
# working on city songea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=raudeberg
# working on city raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=saint-pierre
# working on city saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=waingapu
# working on city waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=lolua
# city not found: lolua
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=temaraia
# city not found: temaraia
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=raduzhnyy
# working on city raduzhnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=avarua
# working on city avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hilo
# working on city hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dakar
# working on city dakar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=upernavik
# working on city upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=klaksvik
# working on city klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=altay
# working on city altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=avera
# working on city avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bambous virieux
# working on city bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=alta floresta
# working on city alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=belushya guba
# city not found: belushya guba
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=guerrero negro
# working on city guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=saint george
# working on city saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=butaritari
# working on city butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=asau
# working on city asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bontang
# working on city bontang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=airai
# working on city airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=saint-philippe
# working on city saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=samarai
# working on city samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=devonport
# working on city devonport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=karaul
# city not found: karaul
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=scottsburgh
# city not found: scottsburgh
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=carnarvon
# working on city carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=cape town
# working on city cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=jiuquan
# working on city jiuquan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=namibe
# working on city namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=taolanaro
# city not found: taolanaro
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=muzquiz
# city not found: muzquiz
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=barentsburg
# city not found: barentsburg
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ilulissat
# working on city ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=qaanaaq
# working on city qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=chapais
# working on city chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=mitchell
# working on city mitchell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=carutapera
# working on city carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=vaini
# working on city vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hobart
# working on city hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=amderma
# city not found: amderma
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=mar del plata
# working on city mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=saskylakh
# working on city saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=yinchuan
# working on city yinchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=yerbogachen
# working on city yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=pangai
# working on city pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=balikpapan
# working on city balikpapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ghanaur
# working on city ghanaur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tonj
# working on city tonj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ancona
# working on city ancona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=saldanha
# working on city saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=grand centre
# city not found: grand centre
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=natal
# working on city natal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=yarumal
# working on city yarumal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=esperance
# working on city esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tura
# working on city tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=codrington
# working on city codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ballina
# working on city ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=illoqqortoormiut
# city not found: illoqqortoormiut
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=comodoro rivadavia
# working on city comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=constitucion
# working on city constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=areka
# working on city areka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=mataura
# working on city mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=obo
# working on city obo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=yaan
# working on city yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hillsborough
# working on city hillsborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=chokurdakh
# working on city chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=christchurch
# working on city christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kavieng
# working on city kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=la ronge
# working on city la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tsihombe
# city not found: tsihombe
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=vanimo
# working on city vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=muisne
# working on city muisne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kieta
# working on city kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=vientiane
# working on city vientiane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nanortalik
# working on city nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=omsukchan
# working on city omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=boa vista
# working on city boa vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=brae
# working on city brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=cidreira
# working on city cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bairiki
# working on city bairiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=busselton
# working on city busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=mahebourg
# working on city mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hazorasp
# working on city hazorasp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=cape canaveral
# working on city cape canaveral
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kjollefjord
# working on city kjollefjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nouakchott
# working on city nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dingle
# working on city dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=pisco
# working on city pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nome
# working on city nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tubruq
# city not found: tubruq
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=aklavik
# working on city aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=yellowknife
# working on city yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=araguari
# working on city araguari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=meulaboh
# working on city meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dikson
# working on city dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=killybegs
# working on city killybegs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=milove
# working on city milove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=spokane
# working on city spokane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kathu
# working on city kathu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dunedin
# working on city dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=georgetown
# working on city georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=boca do acre
# working on city boca do acre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=paradwip
# city not found: paradwip
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=qaqortoq
# working on city qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kawakawa
# working on city kawakawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dannenberg
# working on city dannenberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=borazjan
# working on city borazjan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=sisimiut
# working on city sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bani walid
# working on city bani walid
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kirakira
# working on city kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bredasdorp
# working on city bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=pereslavl-zalesskiy
# working on city pereslavl-zalesskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=lincoln
# working on city lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=pozo colorado
# working on city pozo colorado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=norman wells
# working on city norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=luderitz
# working on city luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=geraldton
# working on city geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ust-kamchatsk
# city not found: ust-kamchatsk
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dhenkanal
# working on city dhenkanal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=atuona
# working on city atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hailar
# working on city hailar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=katsuura
# working on city katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nola
# working on city nola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=baykit
# working on city baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=great yarmouth
# working on city great yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=wilmington
# working on city wilmington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=havre-saint-pierre
# working on city havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=cuamba
# working on city cuamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=trairi
# working on city trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=sechura
# working on city sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=namatanai
# working on city namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hofn
# working on city hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=najran
# working on city najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ceuasul-de campie
# city not found: ceuasul-de campie
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tilichiki
# working on city tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ancud
# working on city ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=port blair
# working on city port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=provideniya
# working on city provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=todos santos
# working on city todos santos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=gumusyaka
# city not found: gumusyaka
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=sulangan
# working on city sulangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=campo maior
# working on city campo maior
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=cockburn town
# working on city cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=severo-yeniseyskiy
# working on city severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=biak
# working on city biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=puerto ayora
# working on city puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nizhneangarsk
# working on city nizhneangarsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=araouane
# working on city araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bengkulu
# working on city bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=marcona
# city not found: marcona
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=sentyabrskiy
# city not found: sentyabrskiy
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=yirol
# city not found: yirol
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=quatre cocos
# working on city quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=peace river
# working on city peace river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hobyo
# working on city hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=lebu
# working on city lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kununurra
# working on city kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kanbe
# working on city kanbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bud
# working on city bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=taoudenni
# working on city taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=san carlos del zulia
# working on city san carlos del zulia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kiunga
# working on city kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=alice springs
# working on city alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ixtapa
# working on city ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=coihaique
# working on city coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=praya
# working on city praya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=thompson
# working on city thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=grand river south east
# city not found: grand river south east
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=marsh harbour
# working on city marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kokkinon
# city not found: kokkinon
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ukiah
# working on city ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=lakatoro
# working on city lakatoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=mwene-ditu
# working on city mwene-ditu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tuatapere
# working on city tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=port lincoln
# working on city port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=monchegorsk
# working on city monchegorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nishihara
# working on city nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=krasnoselkup
# working on city krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nabire
# working on city nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=totness
# working on city totness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=te anau
# working on city te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=berdychiv
# working on city berdychiv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hithadhoo
# working on city hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=angoche
# working on city angoche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=santa maria la alta
# working on city santa maria la alta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=sitka
# working on city sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kloulklubed
# working on city kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=elmadag
# working on city elmadag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=shache
# working on city shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=qandala
# working on city qandala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=azimur
# city not found: azimur
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=luanda
# working on city luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nelson bay
# working on city nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=chicama
# working on city chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=aksarka
# working on city aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tutoia
# working on city tutoia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=svetlogorsk
# working on city svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=jacareacanga
# working on city jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=muros
# working on city muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=fujin
# working on city fujin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hearst
# working on city hearst
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=gushikawa
# working on city gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=puerto madero
# working on city puerto madero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bandarbeyla
# working on city bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=byron bay
# working on city byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=boende
# working on city boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=teya
# working on city teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tingi
# working on city tingi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=portland
# working on city portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=lata
# working on city lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=olafsvik
# working on city olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=fortuna
# working on city fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=fernandez
# working on city fernandez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=vicksburg
# working on city vicksburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=maniitsoq
# working on city maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=yulara
# working on city yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=murindo
# working on city murindo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=labis
# working on city labis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nurota
# working on city nurota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tarudant
# city not found: tarudant
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tazovskiy
# working on city tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tiksi
# working on city tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=roma
# working on city roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=sterling
# working on city sterling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bethel
# working on city bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=cherskiy
# working on city cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dubno
# working on city dubno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hami
# working on city hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=anaconda
# working on city anaconda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=vaitupu
# city not found: vaitupu
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=severo-kurilsk
# working on city severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bathsheba
# working on city bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dhidhdhoo
# working on city dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=erenhot
# working on city erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kuche
# city not found: kuche
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=sur
# working on city sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=shenzhen
# working on city shenzhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=palmer
# working on city palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=udomlya
# working on city udomlya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ponta do sol
# working on city ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ossora
# working on city ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ygatimi
# working on city ygatimi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=takoradi
# working on city takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=pevek
# working on city pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=gisborne
# working on city gisborne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=pampas
# working on city pampas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=velikiy novgorod
# working on city velikiy novgorod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=chuy
# working on city chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=lorengau
# working on city lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=lakes entrance
# working on city lakes entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=clyde river
# working on city clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=turtkul
# city not found: turtkul
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=garwa
# working on city garwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=aguie
# working on city aguie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=abu dhabi
# working on city abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=alyangula
# working on city alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=puerto escondido
# working on city puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nikolayevsk-na-amure
# working on city nikolayevsk-na-amure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=terrace bay
# working on city terrace bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=farsund
# working on city farsund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=griffith
# working on city griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=cervo
# working on city cervo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=weligama
# working on city weligama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=basqal
# working on city basqal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=sao jose da coroa grande
# working on city sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=harper
# working on city harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=imbituba
# working on city imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kazalinsk
# city not found: kazalinsk
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=paamiut
# working on city paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=samusu
# city not found: samusu
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=gulshat
# city not found: gulshat
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=roding
# working on city roding
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=coahuayana
# working on city coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=antananarivo
# working on city antananarivo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=chardara
# working on city chardara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=methoni
# working on city methoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kruisfontein
# working on city kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=edgewater
# working on city edgewater
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=belaya gora
# working on city belaya gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=chingirlau
# working on city chingirlau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=komsomolskiy
# working on city komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=mys shmidta
# city not found: mys shmidta
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=margate
# working on city margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nizhneyansk
# city not found: nizhneyansk
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=laguna
# working on city laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=pierre
# working on city pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bilgoraj
# working on city bilgoraj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=korla
# working on city korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=noumea
# working on city noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=torbay
# working on city torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=salalah
# working on city salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=goundam
# working on city goundam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=solsvik
# city not found: solsvik
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=wasilla
# working on city wasilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=buenaventura
# working on city buenaventura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=togur
# working on city togur
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=rungata
# city not found: rungata
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=khormuj
# city not found: khormuj
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=gurnee
# working on city gurnee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=makakilo city
# working on city makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=iquique
# working on city iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=fremont
# working on city fremont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=sakakah
# working on city sakakah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tezu
# working on city tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=fougamou
# working on city fougamou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=huarmey
# working on city huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ust-ishim
# working on city ust-ishim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bakchar
# working on city bakchar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=san cristobal
# working on city san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=vrangel
# working on city vrangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=gangotri
# city not found: gangotri
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nantucket
# working on city nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=annau
# working on city annau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=barabai
# working on city barabai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tumannyy
# city not found: tumannyy
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hai phong
# city not found: hai phong
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kaitangata
# working on city kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=omboue
# working on city omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=inuvik
# working on city inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=saurimo
# working on city saurimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=yangambi
# working on city yangambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tsabong
# working on city tsabong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ocana
# working on city ocana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=lagoa
# working on city lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=naze
# working on city naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dharangaon
# working on city dharangaon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=zarubino
# working on city zarubino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=skali
# city not found: skali
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=la rioja
# working on city la rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=grindavik
# working on city grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=mezen
# working on city mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=pindushi
# working on city pindushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=podsineye
# working on city podsineye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=prince rupert
# working on city prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kpandae
# working on city kpandae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=teyateyaneng
# working on city teyateyaneng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=mangrol
# working on city mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dandong
# working on city dandong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=leh
# working on city leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=thinadhoo
# working on city thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=forio
# working on city forio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=carlsbad
# working on city carlsbad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=sept-iles
# working on city sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=warah
# working on city warah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kariba
# working on city kariba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dalvik
# working on city dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hun
# working on city hun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=san-pedro
# working on city san-pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=badvel
# working on city badvel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=cap-aux-meules
# working on city cap-aux-meules
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=attawapiskat
# city not found: attawapiskat
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=magadan
# working on city magadan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=saint anthony
# working on city saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=savannah bight
# working on city savannah bight
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=tres lagoas
# working on city tres lagoas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=grand gaube
# working on city grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=praia
# working on city praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=zhezkazgan
# working on city zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kourou
# working on city kourou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=wazzan
# city not found: wazzan
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=great bend
# working on city great bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=mendahara
# city not found: mendahara
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=deputatskiy
# working on city deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=leningradskiy
# working on city leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=petrozavodsk
# working on city petrozavodsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=edd
# working on city edd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=nova olimpia
# working on city nova olimpia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=cairns
# working on city cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=rio verde de mato grosso
# working on city rio verde de mato grosso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=biskamzha
# working on city biskamzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=khorramabad
# working on city khorramabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=cabedelo
# working on city cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kvitok
# working on city kvitok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=linxia
# working on city linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=viedma
# working on city viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=auki
# working on city auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kirkuk
# working on city kirkuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=biltine
# working on city biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hokitika
# working on city hokitika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=itarema
# working on city itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=mason city
# working on city mason city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=halalo
# city not found: halalo
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=challans
# working on city challans
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=metehara
# city not found: metehara
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=rundu
# working on city rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ovre ardal
# working on city ovre ardal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=visnes
# working on city visnes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ketchikan
# working on city ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=caramay
# working on city caramay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ermioni
# working on city ermioni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=zambezi
# working on city zambezi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=the valley
# working on city the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=makung
# city not found: makung
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=hamilton
# working on city hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=ngukurr
# city not found: ngukurr
# 'coord'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=dalby
# working on city dalby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=bhindar
# working on city bhindar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=touros
# working on city touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=kedrovyy
# working on city kedrovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=san vicente
# working on city san vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=fairbanks
# working on city fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=porto belo
# working on city porto belo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=lucapa
# working on city lucapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=talara
# working on city talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=calvia
# working on city calvia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=vestmanna
# working on city vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=oranjemund
# working on city oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=xai-xai
# working on city xai-xai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=stange
# working on city stange
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=manyava
# working on city manyava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=verkhoyansk
# working on city verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20c50570e15a88b47aaa7df2cf8b39e6&q=priiskovyy
# working on city priiskovyy

# %%
#for reference:
#base_url = 'https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=' + api_key
#city = "st. louis"
#full_request = base_url + '&q='+city
#req = requests.get(full_request)
#print(req.text)
# Out:
# {"coord":{"lon":-90.1979,"lat":38.6273},"weather":[{"id":701,"main":"Mist","description":"mist","icon":"50d"}],"base":"stations","main":{"temp":49.66,"feels_like":47.39,"temp_min":48,"temp_max":51.01,"pressure":1015,"humidity":93},"visibility":9656,"wind":{"speed":5.75,"deg":280},"clouds":{"all":90},"dt":1618674425,"sys":{"type":1,"id":3689,"country":"US","sunrise":1618658469,"sunset":1618706338},"timezone":-18000,"id":4407066,"name":"St Louis","cod":200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * OPTIONAL: Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame(city_data)
df
# Out:
#              City  latitude  longitude  temperature  humidity  cloudiness  \
# 0       jamestown   42.0970   -79.2353        40.75        87          90
# 1         ushuaia  -54.8000   -68.3000        53.60        54          75
# 2    vila do maio   15.1333   -23.2167        77.00        57          20
# 3      ngaoundere    7.3167    13.5833        76.01        61         100
# 4           kapaa   22.0752  -159.3190        64.00        59          96
# ..            ...       ...        ...          ...       ...         ...
# 547       xai-xai  -25.0519    33.6442        68.83        60         100
# 548        stange   60.7180    11.1942        56.93        28           0
# 549       manyava   48.6554    24.3754        50.00        57          75
# 550   verkhoyansk   67.5447   133.3850        10.65        76          91
# 551    priiskovyy   51.9333   116.6333        43.32        44          17
#
#      wind speed
# 0          8.05
# 1         16.11
# 2         21.85
# 3          3.78
# 4          1.01
# ..          ...
# 547        6.49
# 548        8.05
# 549        2.24
# 550       12.12
# 551        4.83
#
# [552 rows x 7 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Use matplotlib
# * OPTIONAL: Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
from matplotlib import cm
#put name of dataframe before each element
fig, ax = plt.subplots()
ax.scatter(df["latitude"],df["temperature"], color = "firebrick")
ax.set_title("Latitude vs. temperature (4/17/2021)")
ax.set_xlabel("Latitude (deg)")
ax.set_ylabel("Temperature ($^\circ$F)")
plt.show()
#add axes

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#put name of dataframe before each element
fig, ax = plt.subplots()
ax.scatter(df["latitude"],df["humidity"], color = "goldenrod")
ax.set_title("Latitude vs. humidity (4/17/2021)")
ax.set_xlabel("Latitude (deg)")
ax.set_ylabel("Humidity (%)")
plt.show()
#add axes

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#put name of dataframe before each element
fig, ax = plt.subplots()
ax.scatter(df["latitude"],df["cloudiness"], color = "slategrey")
ax.set_title("Latitude vs. cloudiness (4/17/2021)")
ax.set_xlabel("Latitude (deg)")
ax.set_ylabel("Cloudiness (%)")
plt.show()
#add axes

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#put name of dataframe before each element
fig, ax = plt.subplots()
ax.scatter(df["latitude"],df["wind speed"], color = "skyblue")
ax.set_title("Latitude vs. wind speed (4/17/2021)")
ax.set_xlabel("Latitude (deg)")
ax.set_ylabel("Wind speed (mph)")
plt.show()
#add axes

# %%
#put name of dataframe before each element
fig, ax = plt.subplots()
ax.scatter(df["temperature"],df["humidity"], color = "orangered")
ax.set_title("Temperature vs. humidity (4/17/2021)")
ax.set_xlabel("Temperature ($^\circ$F)")
ax.set_ylabel("Humidity (%)")
plt.show()
#add axes

# %% [markdown]
# ### Use the Seaborn library to re-create 2-4 of the above plots.
# * Use the same data; just make a different plot.
# * Note the differences in amount of code required to generate a similar plot.

# %%
import seaborn as sns
sns.set_palette("RdBu")
g = sns.scatterplot(x="latitude", y="temperature", data=df)
g.set_title("Latitude vs. temperature (4/17/2021)",
           y=1.03)
g.set(xlabel="Latitude (deg)",
     ylabel="Temperature ($^\circ$F)")
plt.show()

# %%
sns.set_palette("PRGn_r")
g = sns.scatterplot(x="temperature", y="humidity", data=df)
g.set_title("Temperature vs. humidity (4/17/2021)",
           y = 1.03)
g.set(xlabel="Temperature ($^\circ$F)",
     ylabel="Humidity (%)")
plt.show()

# %% [markdown]
# ### As a Data-Scientist:
# In addition to generating data, munging data, and plotting data, you will also be responsible for *interpreting* data.
# * Provide a written description of three observable trends based on the data.

# %%
#1: Predictably, temperature decreases as we move further from the equator in either direction. But from the data, we can see that the cities included on Open Weather Map extend further north than south. I would guess this means that settlements have been established further north than south. I looked this up, and it's true. There isn't any land mass between the tip of Chile and Antarctica, and the tip of Chile is not as far from the equator as far Northern Canada is.
#2: Much of the cloudiness data must be rounded to the nearest 2% or 5% or something... That seems like the only plausible explanation for the lines forming at about 0%, 20%, 40%, 75%, and 100%.
#3: It looked like there was a weak correlation between latitude and humidity, with temperatures getting more variable around -40 and 40 degrees. I'd expected higher humidity at latitudes close to the equator because of higher temperatures, so I ran a comparison of temperature and humidity. The humidity was pretty variable at 40 to 90 degrees F, but it was consistently high at sub-zero temperatures and consistently low at 100 degrees. Not at all what I'd anticipated! Maybe it's because at extremely low temperatures, it's snowy all the time, and at extremely high temperatures, it's arid deserts?

# %% [markdown]
# ### OPTIONAL Homework Problem:
# * Use a **different** api endpoint such as `Hourly Forecast 4 days` to get data.
# * Other weather api endpoints are documented [here](https://openweathermap.org/api).
# * You will have to change the URL parameters to get the data you want.
# * Get the data into a data structure of your choice. (Pandas, dicts, lists etc...)
# * Use the plotting library of your choice to make 1-4 plots of your choice.
